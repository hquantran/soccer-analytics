# %% [markdown]
# Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import data

# %%
df=pd.read_csv(r'C:\Users\tranm\Downloads\Soccer_Analytics\data\exports\bi_player_seasons.csv')

# %%
df.head(10)
# Out:
#                    player_season_id  player_id          player_name  \
# 0  8d092dac8488a46c1c7ec9b7dea98c31        130        Nélson Semedo
# 1  eaa0ffac6454d13f59eab7e9619a21aa        168     Davinson Sánchez
# 2  98cf79bda0490aefc606b2690b8c44aa        178          Lucas Moura
# 3  1400f858a8ef26d4a5706e214df143d0        179       Moussa Sissoko
# 4  4feda2f816f7a40d2c5f085ee1479326        284         Joseph Gomez
# 5  80ce7327b9393fb3291e24092f4e5b03        303       Rhian Brewster
# 6  d92c24c922970deb3e45b41cdd495efb        307      Xherdan Shaqiri
# 7  8cbec7bb675d54eb43baea2733964be8        458         Mbaye Diagne
# 8  1002f6e79bbfb6f38d88bfb408246231        567           Rúben Dias
# 9  468a86c45a4c8c179c13a424d77aae59        641  Oleksandr Zinchenko
#
#    nationality                                              photo  height_cm  \
# 0     Portugal  https://media.api-sports.io/football/players/1...      177.0
# ...

# %%
df.shape
# Out:
# (11808, 46)

# %%
df.columns
# Out:
# Index(['player_season_id', 'player_id', 'player_name', 'nationality', 'photo',
#        'height_cm', 'weight_kg', 'age', 'team_id', 'team_name', 'league_id',
#        'league_name', 'season', 'position', 'injured', 'rating', 'appearances',
#        'minutes', 'goals', 'assists', 'shots_total', 'shots_on_target',
#        'passes_total', 'passes_completed', 'passes_key', 'tackles_total',
#        'duels_total', 'duels_won', 'dribbles_attempts', 'dribbles_success',
#        'fouls_drawn', 'fouls_committed', 'cards_yellow', 'cards_red',
#        'goals_per90', 'assists_per90', 'goal_involvements_per90',
#        'key_passes_per90', 'tackles_per90', 'dribbles_per90',
#        'shot_accuracy_pct', 'goal_conversion_pct', 'pass_accuracy_pct',
#        'dribble_success_pct', 'duel_success_pct', 'fouls_per_tackle'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11808 entries, 0 to 11807
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   player_season_id         11808 non-null  str
#  1   player_id                11808 non-null  int64
#  2   player_name              11808 non-null  str
#  3   nationality              11801 non-null  str
#  4   photo                    11808 non-null  str
#  5   height_cm                11772 non-null  float64
#  6   weight_kg                11698 non-null  float64
#  7   age                      11801 non-null  float64
#  8   team_id                  11808 non-null  int64
#  9   team_name                11808 non-null  str
#  10  league_id                11808 non-null  int64
#  11  league_name              11808 non-null  str
#  12  season                   11808 non-null  int64
#  13  position                 11808 non-null  str
# ...

# %%
missing_pct = (df.isna().sum() / len(df)) * 100
missing_pct[missing_pct > 0].sort_values(ascending=False)
# Out:
# pass_accuracy_pct      71.731030
# passes_completed       71.731030
# shot_accuracy_pct       2.642276
# goal_conversion_pct     2.642276
# dribble_success_pct     2.396680
# weight_kg               0.931572
# fouls_per_tackle        0.635163
# height_cm               0.304878
# rating                  0.237127
# duel_success_pct        0.228659
# age                     0.059282
# nationality             0.059282
# dtype: float64

# %%
df.nunique()
# Out:
# player_season_id           11808
# player_id                   4243
# player_name                 4223
# nationality                  119
# photo                       4243
# height_cm                     41
# weight_kg                     48
# age                           29
# team_id                      137
# team_name                    137
# league_id                      5
# league_name                    5
# season                         7
# position                       3
# injured                        1
# rating                      3081
# appearances                   36
# minutes                     2879
# goals                         35
# assists                       21
# shots_total                  114
# shots_on_target               71
# passes_total                2104
# passes_completed            1378
# passes_key                   110
# tackles_total                127
# duels_total                  534
# duels_won                    292
# ...

# %% [markdown]
# Visualization

# %%
# Set global visual style
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Distribution of Minutes Played
sns.histplot(df["minutes"], bins=30, kde=True, ax=axes[0, 0], color="#1f77b4")
axes[0, 0].set_title("1. Distribution of Minutes Played")
axes[0, 0].set_xlabel("Minutes")

# 2. Player Count by Position
sns.countplot(
    data=df, 
    y="position", 
    order=df["position"].value_counts().index, 
    ax=axes[0, 1], 
    palette="viridis"
)
axes[0, 1].set_title("2. Player Count by Position")

# 3. Missing Value Percentage
missing_pct = (df.isnull().sum() / len(df)) * 100
missing_pct = missing_pct[missing_pct > 0].sort_values()
missing_pct.plot(kind="barh", ax=axes[1, 0], color="#d62728")
axes[1, 0].set_title("3. Missing Values (%) per Feature")

# 4. Outlier Detection: Goals vs Shots
sns.scatterplot(
    data=df, 
    x="shots_total", 
    y="goals", 
    hue="position", 
    alpha=0.6, 
    ax=axes[1, 1]
)
axes[1, 1].plot([0, 100], [0, 100], "--", color="gray", label="100% Conversion Line")
axes[1, 1].set_title("4. Goals vs. Total Shots (Outlier Spotting)")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\tranm\AppData\Local\Temp\ipykernel_15488\4033925164.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
