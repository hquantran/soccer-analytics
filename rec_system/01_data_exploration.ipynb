# %% [markdown]
# Libraries

# %%
import pandas as pd

# %% [markdown]
# Import data

# %%
df=pd.read_csv(r'C:\Users\tranm\Downloads\Soccer_Analytics\data\output\player_features.csv')

# %%
df.head(10)
# Out:
#                    player_season_id  player_id             name   age  \
# 0  0070327986e0b3c267de910c7b1d72a8         17       C. Pulišić  28.0
# 1  45272d5311ec297a616f9d67e8372620         44            Rodri  30.0
# 2  34080c9ba355a6b044f03cb4f3960be4         76       M. Nakamba  32.0
# 3  2dd39d6efc367c7b3b28d086e3b5f574        104  Carlos Vinícius  31.0
# 4  8d092dac8488a46c1c7ec9b7dea98c31        130    Nélson Semedo  33.0
# 5  2266ebb54bc4187dd50db5bafd8b00d0        159        H. Lloris  40.0
# 6  c92afd700d9b115a0f650aac75d79c86        162  T. Alderweireld  37.0
# 7  5f3d1cc6fad9279dcc49fe47319c30b5        163        S. Aurier  34.0
# 8  4fa7a75f6f00de81fb980e29001c9ca3        164        B. Davies  33.0
# 9  eaa0ffac6454d13f59eab7e9619a21aa        168       D. Sánchez  30.0
#
#      nationality                                              photo  team_id  \
# 0            USA  https://media.api-sports.io/football/players/1...       49
# ...

# %%
df.shape
# Out:
# (12731, 19)

# %%
df.columns
# Out:
# Index(['player_season_id', 'player_id', 'name', 'age', 'nationality', 'photo',
#        'team_id', 'team_name', 'league_id', 'season', 'position', 'minutes',
#        'rating', 'goals_per90', 'assists_per90', 'key_passes_per90',
#        'tackles_per90', 'dribbles_per90', 'passes_accuracy_pct'],
#       dtype='str')

# %%
(df.isna().sum()/len(df))*100
# Out:
# player_season_id        0.000000
# player_id               0.000000
# name                    0.000000
# age                     0.054984
# nationality             0.054984
# photo                   0.000000
# team_id                 0.000000
# team_name               0.000000
# league_id               0.000000
# season                  0.000000
# position                0.000000
# minutes                 0.000000
# rating                  0.243500
# goals_per90            10.808263
# assists_per90          24.004399
# key_passes_per90        7.140052
# tackles_per90           4.948551
# dribbles_per90          9.535779
# passes_accuracy_pct    72.688713
# dtype: float64
